# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
s=pd.read_csv('/content/car_price_prediction.csv')

# %%
s.head()
# Out:
#          ID  Price  Levy Manufacturer    Model  Prod. year   Category  \
# 0  45654403  13328  1399        LEXUS   RX 450        2010       Jeep
# 1  44731507  16621  1018    CHEVROLET  Equinox        2011       Jeep
# 2  45774419   8467     -        HONDA      FIT        2006  Hatchback
# 3  45769185   3607   862         FORD   Escape        2011       Jeep
# 4  45809263  11726   446        HONDA      FIT        2014  Hatchback
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km        6.0
# 1               No    Petrol             3  192000 km        6.0
# 2               No    Petrol           1.3  200000 km        4.0
# 3              Yes    Hybrid           2.5  168966 km        4.0
# 4              Yes    Petrol           1.3   91901 km        4.0
#
#   Gear box type Drive wheels   Doors             Wheel   Color  Airbags
# 0     Automatic          4x4  04-May        Left wheel  Silver       12
# ...

# %%
s.isnull().sum()
# Out:
# ID                  0
# Price               0
# Levy                0
# Manufacturer        0
# Model               0
# Prod. year          0
# Category            0
# Leather interior    0
# Fuel type           0
# Engine volume       0
# Mileage             0
# Cylinders           0
# Gear box type       0
# Drive wheels        0
# Doors               0
# Wheel               0
# Color               0
# Airbags             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l=LabelEncoder()

# %%
s['manufacture']=l.fit_transform(s['Manufacturer'])

# %%
l1=LabelEncoder()

# %%
s['model']=l1.fit_transform(s['Model'])

# %%
l2=LabelEncoder()

# %%
s['mileage']=l2.fit_transform(s['Mileage'])

# %%
l3=LabelEncoder()

# %%
s['fuel']=l3.fit_transform(s['Fuel type'])

# %%
l4=LabelEncoder()

# %%
s['gear']=l4.fit_transform(s['Gear box type'])

# %%
x=s[['manufacture','mileage','fuel','gear','model']]

# %%
y=s['Price']

# %%
LR=LinearRegression()

# %%
LR.fit(x,y)
# Out:
# LinearRegression()

# %%
LR.predict([[0,0,0,0,0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16842.11556741])
